# %% [markdown]
# <a href="https://colab.research.google.com/github/xthimylJ/daily-practice/blob/main/custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5th December

# %% [markdown]
# ## Getting our custom data (photos) here to google colab, into this notebook

# %%
import torch
import numpy as np
import pandas as pd
import requests
import zipfile
from pathlib import Path

# %%
# setup a data path here in colab
photos = Path("photos/")
emirhan_photos = photos / "emirhan_photos"

#
if emirhan_photos.is_dir():
    print(f"{emirhan_photos} is already exists. No need for downloading")
else:
    print(f"{emirhan_photos} doesn't exist. Creating one...")
    emirhan_photos.mkdir(parents=True, exist_ok=True)

# download photos data
with open(photos / "emirhan_photos.zip", "wb") as f:
    request = requests.get("https://github.com/xthimylJ/photos/raw/refs/heads/main/emirhan%20photos.zip")
    print("downloading Emirhanchik's photos...")
    f.write(request.content)

# unzipping emirhan_photos
with zipfile.ZipFile(photos / "emirhan_photos.zip", "r") as zip_ref:
    print("unzipping photos...")
    zip_ref.extractall(emirhan_photos)
# Out:
# photos/emirhan_photos doesn't exist. Creating one...
# downloading Emirhanchik's photos...
# unzipping photos...

# %% [markdown]
# so the script above is about creating a folder to store custom photos data for training a model

# %% [markdown]
# ## Becoming one with data

# %%
from PIL import Image
import random

# %%
random.seed(69)
image_list = list(emirhan_photos.glob("*/*.jpg"))
image_list
# Out:
# [PosixPath('photos/emirhan_photos/emirhan photos/photo_1_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_3_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_7_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_4_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_8_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_6_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_5_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_9_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_2025-12-05_19-46-38.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_10_2025-12-05_19-47-25.jpg'),
#  PosixPath('photos/emirhan_photos/emirhan photos/photo_2_2025-12-05_19-47-25.jpg')]

# %%
random_image_path = random.choice(image_list)
random_image_path

# open an image
img = Image.open(random_image_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1280>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# # 6th December

# %% [markdown]
# ## visualizing with matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# turn an image into array
img_as_nparr = np.asarray(img)
img_as_nparr
# Out:
# array([[[233, 219, 193],
#         [233, 219, 193],
#         [237, 223, 197],
#         ...,
#         [143, 136, 120],
#         [144, 137, 121],
#         [144, 137, 121]],
#
#        [[230, 216, 190],
#         [218, 204, 178],
#         [218, 204, 178],
#         ...,
#         [144, 137, 121],
#         [144, 137, 121],
#         [145, 138, 122]],
#
#        [[229, 215, 189],
#         [220, 206, 180],
#         [219, 205, 179],
#         ...,
#         [144, 137, 121],
#         [144, 137, 121],
#         [143, 136, 120]],
#
#        ...,
#
#        [[106,  68,  45],
#         [106,  68,  45],
#         [107,  69,  46],
#         ...,
#         [ 49,  37,  25],
#         [ 66,  52,  41],
#         [ 82,  68,  55]],
#
#        [[112,  72,  47],
#         [111,  71,  46],
#         [111,  71,  46],
#         ...,
#         [ 43,  31,  19],
#         [ 57,  43,  32],
#         [ 76,  60,  47]],
#
#        [[112,  72,  47],
#         [110,  70,  45],
#         [110,  70,  45],
# ...

# %%
img_as_nparr.shape
# Out:
# (1280, 960, 3)

# %%
plt.figure(figsize=(10,7))
plt.imshow(img_as_nparr)
plt.show()
